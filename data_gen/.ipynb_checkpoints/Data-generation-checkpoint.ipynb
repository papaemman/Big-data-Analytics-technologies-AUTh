# %% [markdown]
# # Data generation

# %%
# Load modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# HELP: Numpy random number generator functions

# 1. Draw samples from a uniform distribution
np.random.uniform?

# 2. Draw random samples from a multivariate normal distribution
np.random.multivariate_normal?

# %% [markdown]
# ## Experimentation with Distributions

# %%
# Generate data
nb_of_points_sample = 1000
dim_sample = 2

# %% [markdown]
# ### Uniform

# %%
## ---- Uniform distribution -----
df = pd.DataFrame()

for i in range(dim_sample):
    print(f"Create {i} dimension")
    x = np.random.uniform(low=-1, high=1, size=1000)
    df = pd.concat([df, pd.Series(x, name="X"+str(i))], axis=1)
# Out:
# Create 0 dimension
# Create 1 dimension

# %%
# Check dataset
print("Data Dimension:", df.shape)
print("")
print(f"Correlation of df is \n{df.corr()}")
print("")
df.head()
# Out:
# Data Dimension: (1000, 2)
#
# Correlation of df is
#           X0        X1
# X0  1.000000  0.040082
# X1  0.040082  1.000000
#          X0        X1
# 0 -0.678123 -0.298347
# 1 -0.312923 -0.256990
# 2 -0.058811  0.764623
# 3 -0.417638  0.603804
# 4  0.158085  0.852750

# %%
# Plot 2 dimensions
fig = df.plot.scatter(x="X0", y="X1", title="2D Uniform distribution").get_figure()
fig;

# %%
fig.savefig('../assets/2d-uniform.png')

# %% [markdown]
# ### Normal

# %%
## ----  Normal distribution -----
mean_sample = [0, 0]
cov_sample = [[1, 0], [0, 1]] 

x = np.random.multivariate_normal(mean = mean_sample, cov = cov_sample, size=[1000, int(dim_sample/2)])
df = pd.DataFrame(data = x.reshape(1000,dim_sample))

df.columns = ["X"+str(l) for l in list(df.columns)]

# %%
# Check dataset
print("Data Dimension:", df.shape)
print("")
print(f"Correlation of df is \n{df.corr()}")
print("")
df.head()
# Out:
# Data Dimension: (1000, 2)
#
# Correlation of df is
#           X0        X1
# X0  1.000000 -0.028327
# X1 -0.028327  1.000000
#          X0        X1
# 0 -1.767894 -0.429453
# 1  1.697025  1.573672
# 2  1.694850  0.134972
# 3  3.512740  0.433095
# 4 -0.288438 -1.394505

# %%
# Plot 2 dimensions
fig = df.plot.scatter(x="X0", y="X1", title="2D Normal distribution").get_figure()
fig;

# %%
fig.savefig('../assets/2d-normal.png')

# %% [markdown]
# ### Correlated

# %%
## ----  Correlated distribution -----
mean_sample = [0, 0]
cov_sample = [[1, 0.8], [0.8, 1]] 

# Create correlated dim_sample d-space points

x = np.random.multivariate_normal(mean = mean_sample, cov = cov_sample, size=[1000, int(dim_sample/2)])
df = pd.DataFrame(data = x.reshape(1000,dim_sample))

df.columns = ["X"+str(l) for l in list(df.columns)]

# %%
# Check dataset
print("Data Dimension:", df.shape)
print("")
print(f"Correlation of df is \n{df.corr()}")
print("")
df.head()
# Out:
# Data Dimension: (1000, 2)
#
# Correlation of df is
#           X0        X1
# X0  1.000000  0.787502
# X1  0.787502  1.000000
#          X0        X1
# 0  0.784524  0.045554
# 1  1.680808  2.143193
# 2 -0.331593 -0.163927
# 3 -0.874813  1.164035
# 4  1.072294  1.814401

# %%
# Plot 2 dimensions
fig = df.plot.scatter(x="X0", y="X1", title="2D correlated distribution").get_figure()
fig;

# %%
fig.savefig('../assets/2d-correlated.png')

# %% [markdown]
# ### Anti-correlated distribution

# %%
## ----  Anticorrelated distribution -----
mean_sample = [0, 0]
cov_sample = [[1, -0.8], [-0.8, 1]] 

# Create correlated dim_sample d-space points

x = np.random.multivariate_normal(mean = mean_sample, cov = cov_sample, size=[1000, int(dim_sample/2)])
df = pd.DataFrame(data = x.reshape(1000,dim_sample))

df.columns = ["X"+str(l) for l in list(df.columns)]

# %%
# Check dataset
print("Data Dimension:", df.shape)
print("")
print(f"Correlation of df is \n{df.corr()}")
print("")
df.head()
# Out:
# Data Dimension: (1000, 2)
#
# Correlation of df is
#           X0        X1
# X0  1.000000 -0.801636
# X1 -0.801636  1.000000
#          X0        X1
# 0 -0.852849  0.223049
# 1  2.834576 -1.873850
# 2  0.605834 -0.115137
# 3  1.083108 -1.652881
# 4 -2.432922  1.169333

# %%
# Plot 2 dimensions
fig = df.plot.scatter(x="X0", y="X1", title="2D correlated distribution").get_figure()
fig;

# %%
fig.savefig('../assets/2d-anticorrelated.png')

# %% [markdown]
# ## Create datasets

# %%
import gc

# %%
# Define data generation parameters
nb_of_points = [10000, 100000, 1000000]
dim = [2,4,10,50]
distribution = ["uniform", "normal", "correlated","anticorrelated"]

# Define all possible configurations
configurations = [(i,j,k) for i in nb_of_points for j in dim for k in distribution]

print(f"The number of Total configurations (dataset to be created) is {len(configurations)}")
# Out:
# The number of Total configurations (dataset to be created) is 48

# %%
for nb_of_points_sample, dim_sample, distribution_sample in configurations:

    print(f"Generate {nb_of_points_sample} data points, in {dim_sample}-dimensional space, following the {distribution_sample} distribution")
    
    
    df = pd.DataFrame()
    
    
    if distribution_sample == "uniform":
        
        # Create dataset for uniform distribution
        for i in range(dim_sample):
            print(f"Create {i} dimension")
            x = np.random.uniform(low=-1, high=1, size=nb_of_points_sample)
            df = pd.concat([df, pd.Series(x, name="X"+str(i))], axis=1)
         
    else:
        
        if distribution_sample == "normal":
        
            mean_sample = [0, 0]
            cov_sample = [[1, 0], [0, 1]] 
    
    
        elif distribution_sample == "correlated":
        
            mean_sample = [0, 0]
            cov_sample = [[1, 0.8], [0.8, 1]] 
    
    
        elif distribution_sample == "anticorrelated":
    
            mean_sample = [0, 0]
            cov_sample = [[1, -0.8], [-0.8, 1]] 

            
        # Create dataset based on mean and covariance matrix
        x = np.random.multivariate_normal(mean = mean_sample,
                                          cov = cov_sample,
                                          size=[nb_of_points_sample, int(dim_sample/2)])
        
        df = pd.DataFrame(data = x.reshape(nb_of_points_sample,dim_sample))
        df.columns = ["X"+str(l) for l in list(df.columns)]
        
    
    # Save data frame as csv
    path = f"dataset_{nb_of_points_sample}_points_{dim_sample}_dimension_{distribution_sample}_distribution.csv"
    print(f"Save dataset to {path}")
    
    df.to_csv(f"../datasets/{path}", index = False, header=False)
    
    gc.collect()
    print("_"*100)
# Out:
# Generate 10000 data points, in 2-dimensional space, following the uniform distribution
# Create 0 dimension
# Create 1 dimension
# Save dataset to dataset_10000_points_2_dimension_uniform_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 2-dimensional space, following the normal distribution
# Save dataset to dataset_10000_points_2_dimension_normal_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 2-dimensional space, following the correlated distribution
# Save dataset to dataset_10000_points_2_dimension_correlated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 2-dimensional space, following the anticorrelated distribution
# Save dataset to dataset_10000_points_2_dimension_anticorrelated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 4-dimensional space, following the uniform distribution
# Create 0 dimension
# Create 1 dimension
# Create 2 dimension
# Create 3 dimension
# Save dataset to dataset_10000_points_4_dimension_uniform_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 4-dimensional space, following the normal distribution
# Save dataset to dataset_10000_points_4_dimension_normal_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 4-dimensional space, following the correlated distribution
# Save dataset to dataset_10000_points_4_dimension_correlated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 4-dimensional space, following the anticorrelated distribution
# Save dataset to dataset_10000_points_4_dimension_anticorrelated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 10-dimensional space, following the uniform distribution
# Create 0 dimension
# Create 1 dimension
# Create 2 dimension
# Create 3 dimension
# Create 4 dimension
# Create 5 dimension
# Create 6 dimension
# Create 7 dimension
# Create 8 dimension
# Create 9 dimension
# Save dataset to dataset_10000_points_10_dimension_uniform_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 10-dimensional space, following the normal distribution
# Save dataset to dataset_10000_points_10_dimension_normal_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 10-dimensional space, following the correlated distribution
# Save dataset to dataset_10000_points_10_dimension_correlated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 10-dimensional space, following the anticorrelated distribution
# Save dataset to dataset_10000_points_10_dimension_anticorrelated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 50-dimensional space, following the uniform distribution
# Create 0 dimension
# Create 1 dimension
# Create 2 dimension
# Create 3 dimension
# Create 4 dimension
# Create 5 dimension
# Create 6 dimension
# Create 7 dimension
# Create 8 dimension
# Create 9 dimension
# Create 10 dimension
# Create 11 dimension
# Create 12 dimension
# Create 13 dimension
# Create 14 dimension
# Create 15 dimension
# Create 16 dimension
# Create 17 dimension
# Create 18 dimension
# Create 19 dimension
# Create 20 dimension
# Create 21 dimension
# Create 22 dimension
# Create 23 dimension
# Create 24 dimension
# Create 25 dimension
# Create 26 dimension
# Create 27 dimension
# Create 28 dimension
# Create 29 dimension
# Create 30 dimension
# Create 31 dimension
# Create 32 dimension
# Create 33 dimension
# Create 34 dimension
# Create 35 dimension
# Create 36 dimension
# Create 37 dimension
# Create 38 dimension
# Create 39 dimension
# Create 40 dimension
# Create 41 dimension
# Create 42 dimension
# Create 43 dimension
# Create 44 dimension
# Create 45 dimension
# Create 46 dimension
# Create 47 dimension
# Create 48 dimension
# Create 49 dimension
# Save dataset to dataset_10000_points_50_dimension_uniform_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 50-dimensional space, following the normal distribution
# Save dataset to dataset_10000_points_50_dimension_normal_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 50-dimensional space, following the correlated distribution
# Save dataset to dataset_10000_points_50_dimension_correlated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 10000 data points, in 50-dimensional space, following the anticorrelated distribution
# Save dataset to dataset_10000_points_50_dimension_anticorrelated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 2-dimensional space, following the uniform distribution
# Create 0 dimension
# Create 1 dimension
# Save dataset to dataset_100000_points_2_dimension_uniform_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 2-dimensional space, following the normal distribution
# Save dataset to dataset_100000_points_2_dimension_normal_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 2-dimensional space, following the correlated distribution
# Save dataset to dataset_100000_points_2_dimension_correlated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 2-dimensional space, following the anticorrelated distribution
# Save dataset to dataset_100000_points_2_dimension_anticorrelated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 4-dimensional space, following the uniform distribution
# Create 0 dimension
# Create 1 dimension
# Create 2 dimension
# Create 3 dimension
# Save dataset to dataset_100000_points_4_dimension_uniform_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 4-dimensional space, following the normal distribution
# Save dataset to dataset_100000_points_4_dimension_normal_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 4-dimensional space, following the correlated distribution
# Save dataset to dataset_100000_points_4_dimension_correlated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 4-dimensional space, following the anticorrelated distribution
# Save dataset to dataset_100000_points_4_dimension_anticorrelated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 10-dimensional space, following the uniform distribution
# Create 0 dimension
# Create 1 dimension
# Create 2 dimension
# Create 3 dimension
# Create 4 dimension
# Create 5 dimension
# Create 6 dimension
# Create 7 dimension
# Create 8 dimension
# Create 9 dimension
# Save dataset to dataset_100000_points_10_dimension_uniform_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 10-dimensional space, following the normal distribution
# Save dataset to dataset_100000_points_10_dimension_normal_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 10-dimensional space, following the correlated distribution
# Save dataset to dataset_100000_points_10_dimension_correlated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 10-dimensional space, following the anticorrelated distribution
# Save dataset to dataset_100000_points_10_dimension_anticorrelated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 50-dimensional space, following the uniform distribution
# Create 0 dimension
# Create 1 dimension
# Create 2 dimension
# Create 3 dimension
# Create 4 dimension
# Create 5 dimension
# Create 6 dimension
# Create 7 dimension
# Create 8 dimension
# Create 9 dimension
# Create 10 dimension
# Create 11 dimension
# Create 12 dimension
# Create 13 dimension
# Create 14 dimension
# Create 15 dimension
# Create 16 dimension
# Create 17 dimension
# Create 18 dimension
# Create 19 dimension
# Create 20 dimension
# Create 21 dimension
# Create 22 dimension
# Create 23 dimension
# Create 24 dimension
# Create 25 dimension
# Create 26 dimension
# Create 27 dimension
# Create 28 dimension
# Create 29 dimension
# Create 30 dimension
# Create 31 dimension
# Create 32 dimension
# Create 33 dimension
# Create 34 dimension
# Create 35 dimension
# Create 36 dimension
# Create 37 dimension
# Create 38 dimension
# Create 39 dimension
# Create 40 dimension
# Create 41 dimension
# Create 42 dimension
# Create 43 dimension
# Create 44 dimension
# Create 45 dimension
# Create 46 dimension
# Create 47 dimension
# Create 48 dimension
# Create 49 dimension
# Save dataset to dataset_100000_points_50_dimension_uniform_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 50-dimensional space, following the normal distribution
# Save dataset to dataset_100000_points_50_dimension_normal_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 50-dimensional space, following the correlated distribution
# Save dataset to dataset_100000_points_50_dimension_correlated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 100000 data points, in 50-dimensional space, following the anticorrelated distribution
# Save dataset to dataset_100000_points_50_dimension_anticorrelated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 2-dimensional space, following the uniform distribution
# Create 0 dimension
# Create 1 dimension
# Save dataset to dataset_1000000_points_2_dimension_uniform_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 2-dimensional space, following the normal distribution
# Save dataset to dataset_1000000_points_2_dimension_normal_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 2-dimensional space, following the correlated distribution
# Save dataset to dataset_1000000_points_2_dimension_correlated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 2-dimensional space, following the anticorrelated distribution
# Save dataset to dataset_1000000_points_2_dimension_anticorrelated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 4-dimensional space, following the uniform distribution
# Create 0 dimension
# Create 1 dimension
# Create 2 dimension
# Create 3 dimension
# Save dataset to dataset_1000000_points_4_dimension_uniform_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 4-dimensional space, following the normal distribution
# Save dataset to dataset_1000000_points_4_dimension_normal_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 4-dimensional space, following the correlated distribution
# Save dataset to dataset_1000000_points_4_dimension_correlated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 4-dimensional space, following the anticorrelated distribution
# Save dataset to dataset_1000000_points_4_dimension_anticorrelated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 10-dimensional space, following the uniform distribution
# Create 0 dimension
# Create 1 dimension
# Create 2 dimension
# Create 3 dimension
# Create 4 dimension
# Create 5 dimension
# Create 6 dimension
# Create 7 dimension
# Create 8 dimension
# Create 9 dimension
# Save dataset to dataset_1000000_points_10_dimension_uniform_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 10-dimensional space, following the normal distribution
# Save dataset to dataset_1000000_points_10_dimension_normal_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 10-dimensional space, following the correlated distribution
# Save dataset to dataset_1000000_points_10_dimension_correlated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 10-dimensional space, following the anticorrelated distribution
# Save dataset to dataset_1000000_points_10_dimension_anticorrelated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 50-dimensional space, following the uniform distribution
# Create 0 dimension
# Create 1 dimension
# Create 2 dimension
# Create 3 dimension
# Create 4 dimension
# Create 5 dimension
# Create 6 dimension
# Create 7 dimension
# Create 8 dimension
# Create 9 dimension
# Create 10 dimension
# Create 11 dimension
# Create 12 dimension
# Create 13 dimension
# Create 14 dimension
# Create 15 dimension
# Create 16 dimension
# Create 17 dimension
# Create 18 dimension
# Create 19 dimension
# Create 20 dimension
# Create 21 dimension
# Create 22 dimension
# Create 23 dimension
# Create 24 dimension
# Create 25 dimension
# Create 26 dimension
# Create 27 dimension
# Create 28 dimension
# Create 29 dimension
# Create 30 dimension
# Create 31 dimension
# Create 32 dimension
# Create 33 dimension
# Create 34 dimension
# Create 35 dimension
# Create 36 dimension
# Create 37 dimension
# Create 38 dimension
# Create 39 dimension
# Create 40 dimension
# Create 41 dimension
# Create 42 dimension
# Create 43 dimension
# Create 44 dimension
# Create 45 dimension
# Create 46 dimension
# Create 47 dimension
# Create 48 dimension
# Create 49 dimension
# Save dataset to dataset_1000000_points_50_dimension_uniform_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 50-dimensional space, following the normal distribution
# Save dataset to dataset_1000000_points_50_dimension_normal_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 50-dimensional space, following the correlated distribution
# Save dataset to dataset_1000000_points_50_dimension_correlated_distribution.csv
# ____________________________________________________________________________________________________
# Generate 1000000 data points, in 50-dimensional space, following the anticorrelated distribution
# Save dataset to dataset_1000000_points_50_dimension_anticorrelated_distribution.csv
# ____________________________________________________________________________________________________

# %% [markdown]
# ## Sanity check for created datasets

# %%
import pandas as pd
import gc

# %% [markdown]
# **Check created datasets**

# %%
# %%bash
# cd ../datasets
# ls
# Out:
# dataset_1000000_points_10_dimension_anticorrelated_distribution.csv
# dataset_1000000_points_10_dimension_correlated_distribution.csv
# dataset_1000000_points_10_dimension_normal_distribution.csv
# dataset_1000000_points_10_dimension_uniform_distribution.csv
# dataset_1000000_points_2_dimension_anticorrelated_distribution.csv
# dataset_1000000_points_2_dimension_correlated_distribution.csv
# dataset_1000000_points_2_dimension_normal_distribution.csv
# dataset_1000000_points_2_dimension_uniform_distribution.csv
# dataset_1000000_points_4_dimension_anticorrelated_distribution.csv
# dataset_1000000_points_4_dimension_correlated_distribution.csv
# dataset_1000000_points_4_dimension_normal_distribution.csv
# dataset_1000000_points_4_dimension_uniform_distribution.csv
# dataset_1000000_points_50_dimension_anticorrelated_distribution.csv
# dataset_1000000_points_50_dimension_correlated_distribution.csv
# dataset_1000000_points_50_dimension_normal_distribution.csv
# dataset_1000000_points_50_dimension_uniform_distribution.csv
# dataset_100000_points_10_dimension_anticorrelated_distribution.csv
# dataset_100000_points_10_dimension_correlated_distribution.csv
# dataset_100000_points_10_dimension_normal_distribution.csv
# dataset_100000_points_10_dimension_uniform_distribution.csv
# dataset_100000_points_2_dimension_anticorrelated_distribution.csv
# dataset_100000_points_2_dimension_correlated_distribution.csv
# dataset_100000_points_2_dimension_normal_distribution.csv
# dataset_100000_points_2_dimension_uniform_distribution.csv
# dataset_100000_points_4_dimension_anticorrelated_distribution.csv
# dataset_100000_points_4_dimension_correlated_distribution.csv
# dataset_100000_points_4_dimension_normal_distribution.csv
# dataset_100000_points_4_dimension_uniform_distribution.csv
# dataset_100000_points_50_dimension_anticorrelated_distribution.csv
# dataset_100000_points_50_dimension_correlated_distribution.csv
# dataset_100000_points_50_dimension_normal_distribution.csv
# dataset_100000_points_50_dimension_uniform_distribution.csv
# dataset_10000_points_10_dimension_anticorrelated_distribution.csv
# dataset_10000_points_10_dimension_correlated_distribution.csv
# dataset_10000_points_10_dimension_normal_distribution.csv
# dataset_10000_points_10_dimension_uniform_distribution.csv
# dataset_10000_points_2_dimension_anticorrelated_distribution.csv
# dataset_10000_points_2_dimension_correlated_distribution.csv
# dataset_10000_points_2_dimension_normal_distribution.csv
# dataset_10000_points_2_dimension_uniform_distribution.csv
# dataset_10000_points_4_dimension_anticorrelated_distribution.csv
# dataset_10000_points_4_dimension_correlated_distribution.csv
# dataset_10000_points_4_dimension_normal_distribution.csv
# dataset_10000_points_4_dimension_uniform_distribution.csv
# dataset_10000_points_50_dimension_anticorrelated_distribution.csv
# dataset_10000_points_50_dimension_correlated_distribution.csv
# dataset_10000_points_50_dimension_normal_distribution.csv
# dataset_10000_points_50_dimension_uniform_distribution.csv

# %%
# Load a sample dataset

# nb_of_points = [10000, 100000, 1000000]
# dim = [2,4,10,50]
# distribution = ["uniform", "normal", "correlated","anticorrelated"]

nb_of_points_sample = 100000
dim_sample = 10
distribution_sample = "anticorrelated"

path = f"dataset_{nb_of_points_sample}_points_{dim_sample}_dimension_{distribution_sample}_distribution.csv"

df = pd.read_csv(f"../datasets/{path}", index_col=0)

# %%
# Check dataset
print("Data Dimension:", df.shape)
# Out:
# Data Dimension: (100000, 10)

# %%
# Check head
df.head()
# Out:
#          X0        X1        X2        X3        X4        X5        X6  \
# 0 -1.512443  1.704484  1.072766 -0.551516 -0.482011  1.097130 -0.729336
# 1  0.253150 -1.556948 -0.581680  0.225404 -0.814736  1.620514 -0.121246
# 2  0.029391 -0.720863  0.621701  0.288068  1.439878 -1.955270  0.141329
# 3 -0.061454 -0.312797 -1.613206  2.448921 -1.738932  1.133143  1.550519
# 4 -0.016603  0.251878  0.970169 -0.606832  0.136513 -0.536520  0.624490
#
#          X7        X8        X9
# 0 -0.331284  0.709406  0.425278
# 1  0.564242  0.924498  0.310244
# 2 -0.575287  1.636173 -1.668184
# 3 -1.307613  1.243547 -0.532512
# 4 -1.135312 -1.443630  1.953995

# %%
# Check correlations
print("Correlation matrix")
df.corr().style.background_gradient()
# Out:
# Correlation matrix
# <style  type="text/css" >
# #T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col0,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row1_col1,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row2_col2,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row3_col3,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row4_col4,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row5_col5,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row6_col6,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row7_col7,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row8_col8,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row9_col9{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col1,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row1_col0,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row2_col3,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row3_col2,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row4_col5,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row5_col4,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row6_col7,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row7_col6,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row8_col9,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row9_col8{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col2,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col4,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col6,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col8,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row1_col5,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row1_col7,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row2_col0,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row2_col4,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row2_col9,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row4_col0,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row4_col2,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row4_col6,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row4_col8,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row5_col1,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row5_col7,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row5_col9,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row6_col0,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row6_col4,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row7_col1,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row7_col5,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row8_col0,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row8_col4,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row9_col2,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row9_col5{
#             background-color:  #89b1d4;
#             color:  #000000;
#         }#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col3,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col5,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col7,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col9,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row1_col2,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row1_col3,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row1_col8,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row1_col9,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row2_col1,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row2_col5,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row2_col6,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row2_col7,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row2_col8,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row3_col0,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row3_col1,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row3_col4,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row3_col5,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row3_col6,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row3_col7,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row3_col8,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row3_col9,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row4_col3,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row4_col7,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row4_col9,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row5_col0,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row5_col2,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row5_col3,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row5_col6,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row5_col8,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row6_col2,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row6_col3,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row6_col5,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row6_col8,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row6_col9,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row7_col0,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row7_col2,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row7_col3,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row7_col4,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row7_col8,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row7_col9,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row8_col1,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row8_col2,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row8_col3,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row8_col5,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row8_col6,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row8_col7,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row9_col0,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row9_col1,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row9_col3,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row9_col4,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row9_col6,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row9_col7{
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row1_col4,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row1_col6,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row4_col1,#T_f725c6ee_4384_11eb_b127_f730eec0c6b4row6_col1{
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }</style><table id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >X0</th>        <th class="col_heading level0 col1" >X1</th>        <th class="col_heading level0 col2" >X2</th>        <th class="col_heading level0 col3" >X3</th>        <th class="col_heading level0 col4" >X4</th>        <th class="col_heading level0 col5" >X5</th>        <th class="col_heading level0 col6" >X6</th>        <th class="col_heading level0 col7" >X7</th>        <th class="col_heading level0 col8" >X8</th>        <th class="col_heading level0 col9" >X9</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4level0_row0" class="row_heading level0 row0" >X0</th>
#                         <td id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col1" class="data row0 col1" >-0.800290</td>
#                         <td id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col2" class="data row0 col2" >0.004516</td>
#                         <td id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col3" class="data row0 col3" >-0.000304</td>
#                         <td id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col4" class="data row0 col4" >0.006526</td>
#                         <td id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col5" class="data row0 col5" >-0.003080</td>
#                         <td id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col6" class="data row0 col6" >0.003425</td>
#                         <td id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col7" class="data row0 col7" >-0.001159</td>
#                         <td id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col8" class="data row0 col8" >0.003934</td>
#                         <td id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4row0_col9" class="data row0 col9" >-0.002609</td>
#             </tr>
#             <tr>
#                         <th id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4level0_row1" class="row_heading level0 row1" >X1</th>
#                         <td id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4row1_col0" class="data row1 col0" >-0.800290</td>
#                         <td id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4row1_col2" class="data row1 col2" >-0.002765</td>
#                         <td id="T_f725c6ee_4384_11eb_b127_f730eec0c6b4row1_col3" class="data row1 col3" >-0.000272</td>
#                         <td id="T_f725c6ee

# %%
# Plot 2 dimensions
df.plot.scatter(x="X0", y="X1");
